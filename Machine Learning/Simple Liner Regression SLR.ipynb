# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# This is a method for train data
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# ------------------Load Data -----------------------

data = pd.read_csv("Company_Saraly.csv")
data.head(10)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642
# 6              3.0   60150
# 7              3.2   54445
# 8              3.2   64445
# 9              3.7   57189

# %%
#------------------------- Cleaning and organaizing Data -------------------------- 

# out put and input detarmind
real_x = data.iloc[:,0].values # First Columns 0
real_y = data.iloc[:,1].values # Secound Columns 1

# real_x = data['YearsExperience']
# real_y = data['Salary']

real_x = real_x.reshape(-1,1)
real_y = real_y.reshape(-1,1)
# -----------Training data 70-80% 
# -----------Testing data 20-30%
real_y
# Out:
# array([[ 39343],
#        [ 46205],
#        [ 37731],
#        [ 43525],
#        [ 39891],
#        [ 56642],
#        [ 60150],
#        [ 54445],
#        [ 64445],
#        [ 57189],
#        [ 63218],
#        [ 55794],
#        [ 56957],
#        [ 57081],
#        [ 61111],
#        [ 67938],
#        [ 66029],
#        [ 83088],
#        [ 81363],
#        [ 93940],
#        [ 91738],
#        [ 98273],
#        [101302],
#        [113812],
#        [109431],
#        [105582],
#        [116969],
#        [112635],
#        [122391],
#        [121872]], dtype=int64)

# %%
# --------------------------- Spliting data or deviding data --------------------------------------------

training_x,testing_x,training_y,testing_y = train_test_split(real_x,real_y,test_size=0.3,random_state=0)
testing_x
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7],
#        [ 9.6],
#        [ 4. ],
#        [ 5.3]])

# %%
# ---------------------------Using Algorithom --------------------------------------------

Lin = LinearRegression()
Lin.fit(training_x,training_y)  # Fit x,y in algorithom which is help to train
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# --------------------------- Pridect/Testing Data --------------------------------------------

Pred_y = Lin.predict(testing_x) # We alwyas test by using x , not y because y is outpout,, and x is input

testing_y[4] # This is the orginal testing/output data .... y
Pred_y[4] # and This is the predict data which is given by our train model
# Out:
# array([115699.87356004])

# %%
plt.scatter(training_x,training_y,color='green')
plt.plot(training_x,Lin.predict(training_x),color='blue')
plt.title("Salary & Exp Training Plot")
plt.xlabel("Exp")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(testing_x,testing_y,color='green')
plt.plot(training_x,Lin.predict(training_x),color='blue')
plt.title("Salary & Exp Testing Plot")
plt.xlabel("Exp")
plt.ylabel("Salary")
plt.show()

# %%
# -----------------  Equation Results Verification ------------------/


# Y = b1x + b0
Lin.coef_  #This value is for b1
# Out:
# array([[9360.26128619]])

# %%
Lin.intercept_ # this value is for b0
# Out:
# array([26777.3913412])

# %%
9360.26128619*1.5+26777.3913412  #This is for 1.5 year exp salary
9360.26128619*1.3+26777.3913412
9360.26128619*2.0+26777.3913412
9360.26128619*3.7+26777.3913412
9360.26128619*1.0+26777.3913412
# Out:
# 36137.65262739
